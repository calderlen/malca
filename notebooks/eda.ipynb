# %%
from pathlib import Path
import pandas as pd
import numpy as np
import ast
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 10
#       7 sns.set_theme(style="whitegrid")
#       9 csv_path = "path/to/your/peaks_summary.csv"  # TODO: update with the actual path
# ---> 10 df = pd.read_csv(csv_path)
#      11 df.shape
#
# File ~/miniforge3/envs/exo-prt2/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/miniforge3/envs/exo-prt2/lib/python3.11/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/miniforge3/envs/exo-prt2/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniforge3/envs/exo-prt2/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/miniforge3/envs/exo-prt2/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path/to/your/peaks_summary.csv'

# %%
# Load all cleaned peak CSVs into a combined DataFrame
DATA_DIR = Path('/home/calder/Documents/asassn-research/calder/peak_results/cleaned')
csv_paths = sorted(DATA_DIR.glob('peaks_*_clean.csv'))
if not csv_paths:
    raise FileNotFoundError(f'No cleaned peak CSVs found in {DATA_DIR}')

dfs = {}
frames = []
for path in csv_paths:
    frame = pd.read_csv(path)
    frame = frame.copy()
    if 'source_file' not in frame.columns:
        frame['source_file'] = path.name
    else:
        frame['source_file'] = frame['source_file'].fillna(path.name)
    file_key = path.stem
    frame['file_key'] = file_key
    if 'mag_bin' in frame.columns:
        frame['mag_bin'] = frame['mag_bin'].fillna(file_key.replace('peaks_', '').replace('_clean', ''))
    else:
        frame['mag_bin'] = file_key.replace('peaks_', '').replace('_clean', '')
    dfs[file_key] = frame
    frames.append(frame)

df = pd.concat(frames, ignore_index=True)
print(f'Loaded {len(csv_paths)} files with {len(df):,} total rows.')

# %%
# Scrollable display of the combined dataset
from IPython.display import display
max_rows = 500  # adjust if you want a different cap
display(df.head(max_rows).style.set_table_attributes('style="display:inline-block"').set_table_styles([
    {'selector': 'table', 'props': 'max-height: 400px; overflow: auto; display: block;'}
]))

# %%
# Quick structural look at the table
display(df.head())
df.info()

# %%
# Columns that contain stringified Python literals (e.g. "[106, 176, ...]") → convert to real lists
list_like_cols = [
    "g_peaks_idx", "g_peaks_jd",
    "v_peaks_idx", "v_peaks_jd",
]

def parse_literal(value):
    if pd.isna(value) or value == "":
        return []
    try:
        return ast.literal_eval(value)
    except (ValueError, SyntaxError):
        return []

for col in list_like_cols:
    if col in df.columns:
        df[col] = df[col].apply(parse_literal)

# Optional: verify that the reported counts (g_n_peaks / v_n_peaks) match the parsed list lengths
if {"g_n_peaks", "g_peaks_idx"}.issubset(df.columns):
    df["g_peaks_count_check"] = df["g_peaks_idx"].apply(len)
if {"v_n_peaks", "v_peaks_idx"}.issubset(df.columns):
    df["v_peaks_count_check"] = df["v_peaks_idx"].apply(len)

df[["g_n_peaks", "g_peaks_count_check", "v_n_peaks", "v_peaks_count_check"]].head()

# %%
# Descriptive stats for the key fractional columns
fraction_cols = [c for c in ["g_dip_fraction", "g_jump_fraction", "v_dip_fraction", "v_jump_fraction"] if c in df.columns]
df[fraction_cols].describe(percentiles=[0.25, 0.5, 0.75, 0.9, 0.95])

# %%
# Top candidates by g_dip_fraction (and v-band if available)
top_n = 10
cols_for_display = [c for c in ["asas_sn_id", "mag_bin", "g_dip_fraction", "g_n_peaks", "v_dip_fraction", "v_n_peaks", "raw_median_min_camera", "raw_median_max_camera"] if c in df.columns]
display(df.sort_values("g_dip_fraction", ascending=False)[cols_for_display].head(top_n))

if "v_dip_fraction" in df.columns:
    display(df.sort_values("v_dip_fraction", ascending=False)[cols_for_display].head(top_n))

# %%
# Top candidates by g_dip_fraction (and v-band if available)
top_n = 10
cols_for_display = [c for c in ["asas_sn_id", "mag_bin", "g_dip_fraction", "g_n_peaks", "v_dip_fraction", "v_n_peaks", "raw_median_min_camera", "raw_median_max_camera"] if c in df.columns]
display(df.sort_values("g_dip_fraction", ascending=False)[cols_for_display].head(top_n))

if "v_dip_fraction" in df.columns:
    display(df.sort_values("v_dip_fraction", ascending=False)[cols_for_display].head(top_n))

# %%
# Distribution plots for dip fractions and peak counts
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.ravel()

sns.histplot(data=df, x="g_dip_fraction", bins=30, ax=axes[0], color="#1f77b4")
axes[0].set_title("Distribution of g_dip_fraction")

sns.histplot(data=df, x="v_dip_fraction", bins=30, ax=axes[1], color="#ff7f0e")
axes[1].set_title("Distribution of v_dip_fraction")

sns.histplot(data=df, x="g_n_peaks", bins=np.arange(df["g_n_peaks"].max() + 2) - 0.5, ax=axes[2], color="#2ca02c", discrete=True)
axes[2].set_title("g_n_peaks count distribution")

sns.histplot(data=df, x="v_n_peaks", bins=np.arange(df["v_n_peaks"].max() + 2) - 0.5, ax=axes[3], color="#d62728", discrete=True)
axes[3].set_title("v_n_peaks count distribution")

plt.tight_layout()
plt.show()

# %%
# How many targets are marked dip-dominated (g / v), and how often both bands are dip-dominated
dip_dom_summary = {
    "g_is_dip_dominated_true": df["g_is_dip_dominated"].sum(),
    "v_is_dip_dominated_true": df["v_is_dip_dominated"].sum(),
    "both_true": (df["g_is_dip_dominated"] & df["v_is_dip_dominated"]).sum(),
    "either_true": (df["g_is_dip_dominated"] | df["v_is_dip_dominated"]).sum(),
}
pd.Series(dip_dom_summary)

# %%
# Camera perspective: how many unique cameras appear as min/max contributors?
camera_cols = [c for c in ["raw_median_min_camera", "raw_median_max_camera"] if c in df.columns]
camera_counts = {}
for col in camera_cols:
    camera_counts[f"unique_{col}"] = df[col].nunique()
    camera_counts[f"{col}_value_counts"] = df[col].value_counts()
camera_counts

# %%
# Optional: scatter comparing dip fraction vs number of peaks (G-band)
plt.figure(figsize=(8, 6))
sns.scatterplot(
    data=df,
    x="g_n_peaks",
    y="g_dip_fraction",
    hue="g_is_dip_dominated",
    palette={True: "#d62728", False: "#1f77b4"}
)
plt.title("g_dip_fraction vs g_n_peaks")
plt.xlabel("g_n_peaks")
plt.ylabel("g_dip_fraction")
plt.legend(title="g_is_dip_dominated")
plt.tight_layout()
plt.show()

# %%
# Optional: scatter comparing dip fraction vs number of peaks (G-band)
plt.figure(figsize=(8, 6))
sns.scatterplot(
    data=df,
    x="g_n_peaks",
    y="g_dip_fraction",
    hue="g_is_dip_dominated",
    palette={True: "#d62728", False: "#1f77b4"}
)
plt.title("g_dip_fraction vs g_n_peaks")
plt.xlabel("g_n_peaks")
plt.ylabel("g_dip_fraction")
plt.legend(title="g_is_dip_dominated")
plt.tight_layout()
plt.show()

# %%
# Quick table of the columns most relevant to dips/cameras for reporting
report_columns = [
    "asas_sn_id",
    "g_n_peaks", "g_dip_fraction", "g_is_dip_dominated",
    "v_n_peaks", "v_dip_fraction", "v_is_dip_dominated",
    "raw_median_min_camera", "raw_median_max_camera",
]
report_columns = [c for c in report_columns if c in df.columns]
report_df = df[report_columns].copy()
report_df.head(20)

# %%
# Match the known ASAS-SN IDs against the combined dataframe
from IPython.display import display, Markdown
target_ids = [
    335007754417,
    231929175915,
    60130040391,
    377958261591,
    438086977939,
    360777377116,
    635655234580,
    412317159120,
    317827964025,
    438086901547,
    515396514761,
    463856535113,
    120259184943,
    25770019815,
    68720274411,
    644245387906,
    94489418658,
    515397118400,
    661425129485,
    326417831663,
    266288137752,
    532576686103,
    352187470767,
    609886184506,
    455267102087,
    472447294641,
    377957522430,
    601296043597,
    223339338105,
    42950993887,
    549756680252,
    77310927636,
    83014,
    56800,
    60130353420,
    266288912762,
    77310917396,
    128849502096,
]

if 'asas_sn_id' not in df.columns:
    raise KeyError("Combined dataframe is missing the 'asas_sn_id' column")

id_strings = {str(t) for t in target_ids}
mask = df['asas_sn_id'].astype(str).isin(id_strings)
matched = df.loc[mask].copy()

if matched.empty:
    display(Markdown('**No rows matched the requested ASAS-SN IDs.**'))
else:
    summary = (
        matched[['asas_sn_id', 'mag_bin', 'source_file']]
        .drop_duplicates()
        .sort_values('asas_sn_id')
    )
    n_rows = len(matched)
    n_files = summary['source_file'].nunique()
    n_ids = summary['asas_sn_id'].nunique()
    display(Markdown(f'**Matched {n_rows} rows across {n_files} files for {n_ids} unique ASAS-SN IDs.**'))
    styled = summary.style.set_table_attributes("style='display:block; max-height:400px; overflow:auto'")
    try:
        styled = styled.set_sticky(axis=0)
    except (AttributeError, ValueError):
        pass
    display(styled)

matched
# Out:
# **Matched 26 rows across 6 files for 26 unique ASAS-SN IDs.**
# <style type="text/css">
# #T_a400a thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_a400a tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_a400a" style='display:block; max-height:400px; overflow:auto'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a400a_level0_col0" class="col_heading level0 col0" >asas_sn_id</th>
#       <th id="T_a400a_level0_col1" class="col_heading level0 col1" >mag_bin</th>
#       <th id="T_a400a_level0_col2" class="col_heading level0 col2" >source_file</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a400a_level0_row0" class="row_heading level0 row0" >61096</th>
#       <td id="T_a400a_row0_col0" class="data row0 col0" >56800</td>
#       <td id="T_a400a_row0_col1" class="data row0 col1" >13.5_14</td>
#       <td id="T_a400a_row0_col2" class="data row0 col2" >peaks_13_5_14_20251018_155817-0400.csv</td>
#     </tr>
#     <tr>
#       <th id="T_a400a_level0_row1" class="row_heading level0 row1" >61304</th>
#       <td id="T_a400a_row1_col0" class="data row1 col0" >25770019815</td>
#       <td id="T_a400a_row1_col1" class="data row1 col1" >13.5_14</td>
#       <td id="T_a400a_row1_col2" class="data row1 col2" >peaks_13_5_14_20251018_155817-0400.csv</td>
#     </tr>
#     <tr>
#       <th id="T_a400a_level0_row2" class="row_heading level0 row2" >35231</th>
#       <td id="T_a400a_row2_col0" class="data row2 col0" >42950993887</td>
#       <td id="T_a400a_row2_col1" class="data row2 col1" >13_13.5</td>
#       <td id="T_a400a_row2_col2" class="data row2 col2" >peaks_13_13_5_20251018_155817-0400.csv</td>
#     </tr>
#     <tr>
#       <th id="T_a400a_level0_row3" class="row_heading level0 row3" >10150</th>
#       <td id="T_a400a_row3_col0" class="data row3 col0" >60130040391</td>
#       <td id="T_a400a_row3_col1" class="data row3 col1" >12.5_13</td>
#       <td id="T_a400a_row3_col2" class="data row3 col2" >peaks_12_5_13_20251018_155817-0400.csv</td>
#     </tr>
#     <tr>
#       <th id="T_a400a_level0_row4" class="row_heading level0 row4" >35262</th>
#       <td id="T_a400a_row4_col0" class="data row4 col0" >68720274411</td>
#       <td id="T_a400a_row4_col1" class="data row4 col1" >13_13.5</td>
#       <td id="T_a400a_row4_col2" class="data row4 col2" >peaks_13_13_5_20251018_155817-0400.csv</td>
#     </tr>
#     <tr>
#       <th id="T_a400a_level0_row5" class="row_heading level0 row5" >52790</th>
#       <td id="T_a400a_row5_col0" class="data row5 col0" >77310927636</td>
#       <td id="T_a400a_row5_col1" class="data row5 col1" >13.5_14</td>
#       <td id="T_a400a_row5_col2" class="data row5 col2" >peaks_13_5_14_20251018_155817-0400.csv</td>
#     </tr>
#     <tr>
#       <th id="T_a400a_level0_row6" class="row_heading level0 row6" >96617</th>
#       <td id="T_a400a_row6_col0" class="data row6 col0" >94489418658</td>
#       <td id="T_a400a_row6_col1" class="data row6 col1" >13.5_14</td>
#       <td id="T_a400a_row6_col2" class="data row6 col2" >peaks_13_5_14_20251018_155817-0400.csv</td>
#     </tr>
#     <tr>
#       <th id="T_a400a_level0_row7" class="row_heading level0 row7" >42029</th>
#       <td id="T_a400a_row7_col0" class="data row7 col0" >120259184943</td>
#       <td id="T_a400a_row7_col1" class="data row7 col1" >13_13.5</td>
#       <td id="T_a400a_row7_col2" class="data row7 col2" >peaks_13_13_5_20251018_155817-0400.csv</td>
#     </tr>
#     <tr>
#       <th id="T_a400a_level0_row8" class="row_heading level0 row8" >28220</th>
#       <td id="T_a400a_row8_col0" class="data row8 col0" >128849502096</td>
#       <td id="T_a400a_row8_col1" class="data row8 col1" >13_13.5</td>
#       <td id="T_a400a_row8_col2" class="data row8 col2" >peaks_13_13_5_20251018_155817-0400.csv</td>
#     </tr>
#     <tr>
#       <th id="T_a400a_level0_row9" class="row_heading level0 row9" >34518</th>
#       <td id="T_a400a_row9_col0" class="data row9 col0" >223339338105</td>
#       <td id="T_a400a_row9_col1" class="data row9 col1" >13_13.5</td>
#       <td id="T_a400a_row9_col2" class="data row9 col2" >peaks_13_13_5_20251018_155817-0400.csv</td>
#     </tr>
#     <tr>
#       <th id="T_a400a_level0_row10" class="row_heading level0 row10" >187805</th>
#       <td id="T_a400a_row10_col0" class="data row10 col0" >231929175915</td>
#       <td id="T_a400a_row10_col1" class="data row10 col1" >14_14.5</td>
#       <td id="T_a400a_row10_col2" class="data row10 col2" >peaks_14_14_5_20251018_155817-0400.csv</td>
#     </tr>
#     <tr>
#       <th id="T_a400a_level0_row11" class="row_heading level0 row11" >55454</th>
#       <td id="T_a400a_row11_col0" class="data row11 col0" >266288912762</td>
#       <td id="T_a400a_row11_col1" class="data row11 col1" >13.5_14</td>
#       <td id="T_a400a_row11_col2" class="data row11 col2" >peaks_13_5_14_20251018_155817-0400.csv</td>
#     </tr>
#     <tr>
#       <th id="T_a400a_level0_row12" class="row_heading level0 row12" >40785</th>
#       <td id="T_a400a_row12_col0" class="data row12 col0" >326417831663</td>
#       <td id="T_a400a_row12_col1" class="data row12 col1" >13_13.5</td>
#       <td id="T_a400a_row12_col2" class="data row12 col2" >peaks_13_13_5_20251018_155817-0400.csv</td>
#     </tr>
#     <tr>
#       <th id="T_a400a_level0_row13" class="row_heading level0 row13" >321704</th>
#       <td id="T_a400a_row13_col0" class="data row13 col0" >335007754417</td>
#       <td id="T_a400a_row13_col1" class="data row13 col1" >14.5_15</td>
#       <td id="T_a400a_row13_col2" class="data row13 col2" >peaks_14_5_15_20251018_155817-0400.csv</td>
#     </tr>
#     <tr>
#       <th id="T_a400a_level0_row14" class="row_heading level0 row14" >44866</th>
#       <td id="T_a400a_row14_col0" class="data row14 col0" >360777377116</td>
#       <td id="T_a400a_row14_col1" class="data row14 col1" >13_13.5</td>
#       <td id="T_a400a_row14_col2" class="data row14 col2" >peaks_13_13_5_20251018_155817-0400.csv</td>
#     </tr>
#     <tr>
#       <th id="T_a400a_level0_row15" class="row_heading level0 row15" >30926</th>
#       <td id="T_a400a_row15_col0" class="data row15 col0" >377957522430</td>
#       <td id="T_a400a_row15_col1" class="data row15 col1" >13_13.5</td>
#       <td id="T_a400a_row15_col2" class="data row15 col2" >peaks_13_13_5_20251018_155817-0400.csv</td>
#     </tr>
#     <tr>
#       <th id="T_a400a_level0_row16" class="row_heading level0 row16" >95877</th>
#       <td id="T_a400a_row16_col0" class="data row16 col0" >377958261591</td>
#       <td id="T_a400a_row16_col1" class="data row16 col1" >13.5_14</td>
#       <td id="T_a400a_row16_col2" class="data row16 col2" >peaks_13_5_14_20251018_155817-0400.csv</td>
#     </tr>
#     <tr>
#       <th id="T_a400a_level0_row17" class="row_heading level0 row17" >80054</th>
#       <td id="T_a400a_row17_col0" class="data row17 col0" >412317159120</td>
#       <td id="T_a400a_row17_col1" class="data row17 col1" >13.5_14</td>
#       <td id="T_a400a_row17_col2" class="data row17 col2" >peaks_13_5_14_20251018_155817-0400.csv</td>
#     </tr>
#     <tr>
#       <th id="T_a400a_level0_row18" class="row_heading level0 row18" >82255</th>
#       <td id="T_a400a_row18_col0" class="data row18 col0" >438086901547</td>
#       <td id="T_a400a_row18_col1" class="data row18 col1" >13.5_14</td>
#       <td id="T_a400a_row18_col2" class="data row18 col2" >peaks_13_5_14_20251018_155817-0400.csv</td>
#     </tr>
#     <tr>
#       <th id="T_a400a_level0_row19" class="row_heading level0 row19" >58434</th>
#       <td id="T_a400a_row19_col0" class="data row19 col0" >438086977939</td>
#       <td id="T_a400a_row19_col1" class="data row19 col1" >13.5_14</td>
#       <td id="T_a400a_row19_col2" class="data row19 col2" >peaks_13_5_14_20251018_155817-0400.csv</td>
#     </tr>
#     <tr>
#       <th id="T_a400a_level0_row20" class="row_heading level0 row20" >36067</th>
#       <td id="T_a400a_row20_col0" class="data row20 col0" >463856535113</td>
#       <td id="T_a400a_row20_col1" class="data row20 col1" >13_13.5</td>
#       <td id="T_a400a_row20_col2" class="data row20 col2" >peaks_13_13_5_20251018_155817-0400.csv</td>
#     </tr>
#     <tr
#         mag_bin    asas_sn_id  index_num  \
# 1547    12_12.5  644245387906         11
# 10150   12.5_13   60130040391         10
# 24265   13_13.5  635655234580         10
# 26499   13_13.5  472447294641         13
# 28220   13_13.5  128849502096         15
# 30926   13_13.5  377957522430         18
# 34518   13_13.5  223339338105         21
# 35231   13_13.5   42950993887         22
# 35262   13_13.5   68720274411         22
# 36067   13_13.5  463856535113         23
# 40785   13_13.5  326417831663         29
# 42029   13_13.5  120259184943          2
# 44866   13_13.5  360777377116          5
# 52790   13.5_14   77310927636         13
# 54362   13.5_14  515397118400         14
# 55454   13.5_14  266288912762         15
# 58434   13.5_14  438086977939         18
# 61096   13.5_14         56800          1
# 61304   13.5_14   25770019815         20
# 73586   13.5_14  515396514761          2
# 80054   13.5_14  412317159120         35
# 82255   13.5_14  438086901547         36
# 95877   13.5_14  377958261591          9
# 96617   13.5_14   94489418658          9
# 187805  14_14.5  231929175915         51
# 321704  14.5_15  335007754417          2
#
#                                                 index_csv  \
# 1547    /data/poohbah/1/assassin/lenhart/code/calder/l...
# 10150   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 24265   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 26499   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 28220   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 30926   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 34518   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 35231   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 35262   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 36067   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 40785   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 42029   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 44866   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 52790   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 54362   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 55454   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 58434   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 61096   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 61304   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 73586   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 80054   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 82255   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 95877   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 96617   /data/poohbah/1/assassin/lenhart/code/calder/l...
# 187805  /data/poohbah/1/assassin/lenhart/code/calder/l...
# 321704  /data/poohbah/1/assassin/lenhart/code/calder/l...
#
#                                                    lc_dir  \
# 1547    /data/poohbah/1/assassin/rowan.90/lcsv2/12_12....
# 10150   /data/poohbah/1/assassin/rowan.90/lcsv2/12.5_1...
# 24265   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 26499   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 28220   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 30926   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 34518   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 35231   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 35262   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 36067   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 40785   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 42029   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 44866   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 52790   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 54362   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 55454   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 58434   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 61096   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 61304   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 73586   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 80054   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 82255   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 95877   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 96617   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 187805  /data/poohbah/1/assassin/rowan.90/lcsv2/14_14....
# 321704  /data/poohbah/1/assassin/rowan.90/lcsv2/14.5_1...
#
#                                                  dat_path  \
# 1547    /data/poohbah/1/assassin/rowan.90/lcsv2/12_12....
# 10150   /data/poohbah/1/assassin/rowan.90/lcsv2/12.5_1...
# 24265   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 26499   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 28220   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 30926   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 34518   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 35231   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 35262   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 36067   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 40785   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 42029   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 44866   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....
# 52790   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 54362   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 55454   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 58434   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 61096   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 61304   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 73586   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 80054   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 82255   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 95877   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 96617   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...
# 187805  /data/poohbah/1/assassin/rowan.90/lcsv2/14_14....
# 321704  /data/poohbah/1/assassin/rowan.90/lcsv2/14.5_1...
#
#                                                  raw_path  g_n_peaks  \
# 1547    /data/poohbah/1/assassin/rowan.90/lcsv2/12_12....          1
# 10150   /data/poohbah/1/assassin/rowan.90/lcsv2/12.5_1...          2
# 24265   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....          1
# 26499   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....          1
# 28220   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....          4
# 30926   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....          7
# 34518   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....          1
# 35231   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....          1
# 35262   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....          3
# 36067   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....          1
# 40785   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....          2
# 42029   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....          1
# 44866   /data/poohbah/1/assassin/rowan.90/lcsv2/13_13....          1
# 52790   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...          3
# 54362   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...          2
# 55454   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...          3
# 58434   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...          1
# 61096   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...          1
# 61304   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...          1
# 73586   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...          1
# 80054   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...          1
# 82255   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...          1
# 95877   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...          1
# 96617   /data/poohbah/1/assassin/rowan.90/lcsv2/13.5_1...          1
# 187805  /data/poohbah/1/assassin/rowan.90/lcsv2/14_14....          1
# 321704  /data/poohbah/1/assassin/rowan.90/lcsv2/14.5_1...          3
#
#         g_mean_mag                         g_peaks_idx  ...    dec_deg  pm_ra  \
# 1547     12.453439                               [528]  ... -58.130373  -3.31
# 10150    12.740053                             [4, 51]  ...  56.931252   6.69
# 24265    13.065357                               [328]  ... -54.999639  -5.43
# 26499    13.228011                               [666]  ... -47.547294  -0.77
# 28220    13.284065                [201, 245, 331, 408]  ...  30.724819  -3.40
# 30926    13.345646  [61, 259, 383, 528, 620, 733, 769]  ...  15.424939   3.29
# 34518    13.369203                               [473]  ...  34.554054   1.06
# 35231    13.114329                               [660]  ...  38.660551  -3.04
# 35262    13.451504                     [120, 440, 750]  ...  64.729811  -2.83
# 36067    13.410329                                [21]  ... -71.587087   5.65
# 40785    13.473585                         [684, 1001]  ... -12.165664   1.38
# 42029    13.146768                               [802]  ...  48.027853  -2.63
# 44866    13.104017                              [1549]  ... -16.268967  -1.66
# 52790    13.616066                     [240, 666, 955]  ...  29.313722  -3.51
# 54362    13.543089                         [358, 1105]  ... -62.465455  -5.91
# 55454    13.718709                    [33, 1561, 1636]  ... -82.088594  12.82
# 58434    13.002886                                [15]  ... -27.487761  -1.06
# 61096    13.529733                              [3076]  ... -79.680577   1.35
# 61304    13.826543                               [313]  ...  56.386633  -3.29
# 73586    13.605573                               [703]  ... -19.960933  -4.13
# 80054    13.957466                                [86]  ... -44.713081  -0.63
# 82255    13.873213                               [589]  ... -31.807145  -4.48
# 95877    13.678097                              [1114]  ...  -7.894645  -0.61
# 96617    13.603270                               [320]  ...  63.587557  -5.37
# 187805   14.529254                               [117]  ...   1.526290   0.98
# 321704   14.475391                   [258, 1227, 2420]  ... -20.013585  -2.65
#
#         pm_ra_d pm_dec pm_dec_d  vsx_match_sep_arcsec  vsx_class  \
# 1547       0.14  -1.77     0.11            226.653605        NaN
# 10150      0.04  -2.11     0.04            466.417296        NaN
# 24265      0.04   3.28     0.04             68.529369        NaN
# 26499      0.06  -2.80     0.06           1295.365891        NaN
# 28220      0.05 -11.58     0.04           4859.174260        NaN
# 30926      0.08  -3.14     0.07            954.815746        NaN
# 34518      0.02  -2.97     0.03           2040.602646        NaN
# 35231      0.04  -7.39     0.04            364.068832        NaN
# 35262      0.03   0.03     0.03            387.235256        NaN
# 36067      0.02  -4.29     0.03            814.435580        NaN
# 40785      0.08  -2.87     0.07           1521.195055        NaN
# 42029      0.08   0.10     0.10              0.014069        VAR
# 44866      0.06   1.26     0.05            348.394295        NaN
# 52790      0.12  -2.99     0.12            859.821988        NaN
# 54362      0.04  -1.08     0.05            251.699482        NaN
# 55454      0.02  -3.71     0.02            472.858660        NaN
# 58434      0.03   1.98     0.04            432.245346        NaN
# 61096      0.03  -8.45     0.03           2305.945654        NaN
# 61304      0.04  -0.16     0.04            207.578584        NaN
# 73586      0.06  -2.79     0.06            606.254190        NaN
# 80054      0.09  -3.13     0.05            690.621649        NaN
# 82255      0.12  -5.18     0.09            269.667166        NaN
# 95877      0.06  -2.19     0.06            353.945543        NaN
# 96617      0.03  -1.38     0.03            786.951866        NaN
# 187805     0.04  -8.06     0.04            286.933544        NaN
# 321704     0.02   2.35     0.03            213.554874        NaN
#
#                    file_key  g_peaks_count_check  v_peaks_count_check
# 1547    peaks_12_12_5_clean                    1                    0
# 10150   peaks_12_5_13_clean                    2                    0
# 24265   peaks_13_13_5_clean                    1                    0
# 26499   peaks_13_13_5_clean                    1                    0
# 28220   peaks_13_13_5_clean                    4                    4
# 30926   peaks_13_13_5_clean                    7                    2
# 34518   peaks_13_13_5_clean                    1                    0
# 35231   peaks_13_13_5_clean                    1                    0
# 35262   peaks_13_13_5_clean                    3                    0
# 36067   peaks_13_13_5_clean                    1                    0
# 40785   peaks_13_13_5_clean                    2                    1
# 42029   peaks_13_13_5_clean                    1                    0
# 44866   peaks_13_13_5_clean                    1                    0
# 52790   peaks_13_5_14_clean                    3                    2
# 54362   peaks_13_5_14_clean                    2                    0
# 55454   peaks_13_5_14_clean                    3                    0
# 58434   peaks_13_5_14_clean                    1                    0
# 61096   peaks_13_5_14_clean                    1                    0
# 61304   peaks_13_5_14_clean                    1                    0
# 73586   peaks_13_5_14_clean                    1                    0
# 80054   peaks_13_5_14_clean                    1                    0
# 82255   peaks_13_5_14_clean                    1                    0
# 95877   peaks_13_5_14_clean                    1                    0
# 96617   peaks_13_5_14_clean                    1                    0
# 187805  peaks_14_14_5_clean                    1                    0
# 321704  peaks_14_5_15_clean                    3                    0
#
# [26 rows x 62 columns]

# %%
found_ids = set(summary["asas_sn_id"])
missing_ids = sorted(set(target_ids) - found_ids)
missing_ids
# Out:
# [83014,
#  60130353420,
#  77310917396,
#  266288137752,
#  317827964025,
#  352187470767,
#  455267102087,
#  532576686103,
#  549756680252,
#  601296043597,
#  609886184506,
#  661425129485]
